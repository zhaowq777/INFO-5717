# %%
from collections import Counter
text = "Harry lay in his dark cupboard much later, wishing he had a watch. He didn't know what time it was and he couldn't be sure the Dursleys were asleep yet. Until they were, he couldn't risk sneaking to the kitchen for some food. He'd lived with the Dursleys almost ten years, ten miserable years, as long as he could remember, ever since he'd been a baby and his parents had died in that car crash. He couldn't remember being in the car when his parents had died. Sometimes, when he strained his memory during long hours in his cupboard, he came up with a strange vision: a blinding flash of green light and a burning pain on his forehead. This, he supposed, was the crash, though he couldn't imagine where all the green light came from. He couldn't remember his parents at all. His aunt and uncle never spoke about them, and of course he was forbidden to ask questions. There were no photographs of them in the house."
words = text.replace(',','').replace('.','').split(" ")
tepdic = []

strlist = ['a','e', 'i', 'o', 'u']
for word in words:
       if word[0] in strlist:
            tepdic.append(word)
            
c = Counter(tepdic)
print(c)
    
aplist = []
for word in words:
       if "'"in word:
           aplist.append(word)
           print (word)
         
stopwords = "a about above after again against all am an and any are aren't as at be because been before being below between both but by can't cannot could couldn't did didn't do does doesn't doing don't down during each few for from further had hadn't has hasn't have haven't having he he'd he'll he's her here here's hers herself him himself his how how's i i'd i'll i'm i've if in into is isn't it it's its itself let's me more most mustn't my myself no nor not of off on once only or other ought our ours ourselves out over own same shan't she she'd she'll she's should shouldn't so some such than that that's the their theirs them themselves then there there's these they they'd they'll they're they've this those through to too under until up very was wasn't we we'd we'll we're we've were weren't what what's when when's where where's which while who who's whom why why's with won't would wouldn't you you'd you'll you're you've your yours yourself yourselves"
stoplist = stopwords.split(" ")

answer3 = ""
for word in words:
    if word not in aplist and word not in stoplist:
        answer3 = answer3 + word + " " 
print (answer3)
# Out:
# Counter({'in': 5, 'a': 5, 'and': 5, 'of': 3, 'as': 2, 'all': 2, 'it': 1, 'asleep': 1, 'almost': 1, 'ever': 1, 'up': 1, 'on': 1, 'imagine': 1, 'at': 1, 'aunt': 1, 'uncle': 1, 'about': 1, 'ask': 1})
# didn't
# couldn't
# couldn't
# He'd
# he'd
# couldn't
# couldn't
# couldn't
# Harry lay dark cupboard much later wishing watch He know time sure Dursleys asleep yet Until risk sneaking kitchen food lived Dursleys almost ten years ten miserable years long remember ever since baby parents died car crash He remember car parents died Sometimes strained memory long hours cupboard came strange vision: blinding flash green light burning pain forehead This supposed crash though imagine green light came He remember parents His aunt uncle never spoke course forbidden ask questions There photographs house

# %%
import csv
import numpy as np

f_1 = open (r"C:\Users\zhaow\OneDrive\Wen\IS PHD\INFO 5717 Networked Data Modeling and Processing\Assignment III\2011-Jan-June.csv","r")
reader = csv.reader(f_1)

listhigh11 = []
listlow11 = []
listpreci11 = []


for item in reader:
    listhigh11.append(int(item[1]))
    listlow11.append(int(item[2]))
    listpreci11.append(float(item[3]))

highmean11 = np.mean(listhigh11) 
highmedian11 = np.median(listhigh11) 
highsd11 = np.std(listhigh11,ddof=1)

lowmean11 = np.mean(listlow11) 
lowmedian11 = np.median(listlow11) 
lowsd11 = np.std(listlow11,ddof=1)

precimean11 = np.mean(listpreci11) 
precimedian11 = np.median(listpreci11) 
precisd11 = np.std(listpreci11,ddof=1)

f_1 = open (r"C:\Users\zhaow\OneDrive\Wen\IS PHD\INFO 5717 Networked Data Modeling and Processing\Assignment III\2018-Jan-June.csv","r")
reader = csv.reader(f_1)

listhigh18 = []
listlow18 = []
listpreci18 = []


for item in reader:
    listhigh18.append(int(item[1]))
    listlow18.append(int(item[2]))
    listpreci18.append(float(item[3]))

highmean18 = np.mean(listhigh18) 
highmedian18 = np.median(listhigh18) 
highsd18 = np.std(listhigh18,ddof=1)

lowmean18 = np.mean(listlow18) 
lowmedian18 = np.median(listlow18) 
lowsd18 = np.std(listlow18,ddof=1)

precimean18 = np.mean(listpreci18) 
precimedian18 = np.median(listpreci18) 
precisd18 = np.std(listpreci18,ddof=1)


            
print("File name" + "           "+ "mean" + "                "+ "median" + "       "+ "standard deviation")
print("2011-Jan-June.csv" + "  " + str(highmean11) + "       " + str(highmedian11) + "       " + str(highsd11))
print("2011-Jan-June.csv" + "  " + str(lowmean11) + "     " + str(lowmedian11) + "       " + str(lowsd11))
print("2011-Jan-June.csv" + "  " + str(precimean11) + "     " + str(precimedian11) + "         " + str(precisd11))

print("2018-Jan-June.csv" + "  " + str(highmean18) + "      " + str(highmedian18) + "        " + str(highsd18))
print("2018-Jan-June.csv" + "  " + str(lowmean18) + "      " + str(lowmedian18) + "       " + str(lowsd18))
print("2018-Jan-June.csv" + "  " + str(precimean18) + "     " + str(precimedian18) + "        " + str(precisd18))
# Out:
# File name           mean                median       standard deviation
# 2011-Jan-June.csv  73.5524861878453       77.0       19.39426481394485
# 2011-Jan-June.csv  50.011049723756905     49.0       18.510654274491113
# 2011-Jan-June.csv  0.1058563535911602     0.0         0.43081055558868314
# 2018-Jan-June.csv  73.06629834254143      73.0        17.293095028538204
# 2018-Jan-June.csv  49.386740331491715      47.0       17.64037795274044
# 2018-Jan-June.csv  0.08033149171270719     0.0        0.30312428795331936

# %%
from collections import OrderedDict
import random

class Student :
    'students information'
    classes_token = OrderedDict()
    classes_token['c_number'] = ''
    classes_token['s_number'] = ''
    classes_token['grade'] = ''
    euid = ''
    gpa = 0 
    list = []
    
    def __init__(self, first_name, last_name, middle_name):
      self.first_name = first_name
      self.last_name = last_name
      self.middle_name = middle_name
      self.list.append( first_name+"  "+last_name+ "  "+ middle_name)
      
    def set_euid(self):
        flm = self.first_name[0] + self.middle_name[0] + self.last_name[0] + str(random.randint(0,9)) + str(random.randint(0,9)) + str(random.randint(0,9)) + str(random.randint(0,9))
        self.euid = flm
        print (self.euid)
        
    def register(self, c_number, semester, grade ):
       self.classes_token['c_number'] = c_number
       self.classes_token['s_number'] = semester
       self.classes_token['grade'] = grade
       self.list.append(self.classes_token)
       
       if grade == 'A':
           kk = 4
       if grade == 'B':
           kk = 3
       if grade == 'c':
           kk = 2
       if grade == 'D':
           kk = 1
           
       self.gpa = self.gpa + kk
   
    def getName(self):
        return(self.first_name+"  "+self.last_name+ "  "+ self.middle_name)
       
       
    def setgpa(self):
         return self.gpa/len(self.list)
        
        
      
'first student information'
for i in range(1):
    f_name_a = input("first_name:")
    l_name_a = input("last_name:")
    m_name_a = input("middle_name:")
    studentA = Student(f_name_a,m_name_a,l_name_a)
    studentA.set_euid()

    cno = input("please input the number of courses:")
    
    for i in range(int(cno)):
        c_number = input("class number:")
        semester = input("semester:")
        grade = input("grade:")
        studentA.register(c_number, semester, grade)

    print(studentA.getName())
    print(studentA.setgpa())
# Out:
# first_name:Ben
# last_name:Sam
# middle_name:William
# BSW5911
# please input the number of courses:3
# class number:5200
# semester:Fall2019
# grade:A
# class number:5700
# semester:Fall2019
# grade:B
# class number:7700
# semester:Fall2019
# grade:A
# Ben  William  Sam
# 2.75
