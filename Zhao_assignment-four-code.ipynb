# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="user",
  passwd="123456",
  database="test"
)
mycursor = mydb.cursor()


import tweepy
consumer_key = "u7L1lnR7HN85dn1qnTFO1cegb"
consumer_secret = "QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT"
access_token = "1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO"
access_token_secret = "gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

test_user = api.get_user("Zhao")
user_info = [test_user.screen_name,
             test_user.name,
             test_user.location,
             test_user.description,
             test_user.followers_count,
             test_user.friends_count,
             test_user.statuses_count,
             test_user.url]

mycursor.execute("INSERT INTO customers(screenname, username, userlocation, description, followsnumber, friendsnumber, statuses, url) VALUES(%s,%s,%s,%s,%s,%s,%s,%s)", user_info)
print(user_info)
# Out:
# ['zhao', '上坟山7号', '', 'powder lude ing', 133, 472, 14, None]

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="user",
  passwd="123456",
  database="test"
)
mycursor = mydb.cursor()


import tweepy
consumer_key = "u7L1lnR7HN85dn1qnTFO1cegb"
consumer_secret = "QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT"
access_token = "1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO"
access_token_secret = "gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
usernames = ["realDonaldTrump",
             "HillaryClinton",
             "Jumpman23",
             "WaltDisney",
             "JHarden13",
             "AlitaSequel",
             "DisneyStudios",
             "DisneysMulan",
             "Jim_Jordan",
             "shanedawson"]
    
for user in usernames:
    test_user = api.get_user(user)
    user_info = [test_user.screen_name,
                 test_user.name,
                 test_user.location,
                 test_user.description,
                 test_user.followers_count,
                 test_user.friends_count,
                 test_user.statuses_count,
                 test_user.url]
    print(user_info)
mycursor.execute("INSERT INTO customers(screenname, username, userlocation, description, followsnumber, friendsnumber, statuses, url) VALUES(%s,%s,%s,%s,%s,%s,%s,%s)", user_info)
# Out:
# ['realDonaldTrump', 'Donald J. Trump', 'Washington, DC', '45th President of the United States of America🇺🇸', 67270187, 47, 46651, 'https://t.co/OMxB0x7xC5']
# ['HillaryClinton', 'Hillary Clinton', 'New York, NY', '2016 Democratic Nominee, SecState, Senator, hair icon. Mom, Wife, Grandma x3, lawyer, advocate, fan of walks in the woods & standing up for our democracy.', 26010157, 808, 11312, 'https://t.co/99DVW9q1yt']
# ['Jumpman23', 'Jordan', '', '#JUMPMAN', 3812173, 127, 9941, 'https://t.co/khbd6TxFzL']
# ['waltdisney', 'waltdisney', '', '', 366, 0, 0, None]
# ['JHarden13', 'James Harden', '', 'NBA Player for the Houston Rockets.', 6517772, 240, 13036, None]
# ['AlitaSequel', 'Alita Sequel', '', '', 6, 4, 3, None]
# ['DisneyStudios', 'Walt Disney Studios', 'Los Angeles, CA', 'The official Twitter for Walt Disney Studios where we can share news, videos, pics, and more from upcoming films with our fans!', 5953945, 285, 10946, 'https://t.co/7qW3qQl2VJ']
# ...

# %%
import time

import tweepy

consumer_key = "u7L1lnR7HN85dn1qnTFO1cegb"
consumer_secret = "QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT"
access_token = "1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO"
access_token_secret = "gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# #user = api.me()
user = api.get_user("zhao")
# print (user)
network_connections = []


counter_i = 1 
counter_j = 1
ids = []
for page in tweepy.Cursor(api.followers_ids, screen_name="zhao").pages():
    ids.extend(page)
    time.sleep(60)

#     print (ids)

for follower in ids:
        connect = (user.id,follower)
#         print (connect)
        network_connections.append(connect)
        for friend in ids(follower):
            connect_ = (follower,friend)
            network_connections.append(connect_)
            counter_i+=1
            if counter_i == 5: break
        counter_j+=1
        if counter_j == 10: break
# print(network_connections)
x,y = zip(*network_connections)



import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
 
df = pd.DataFrame({ 'from':x, 'to':y})

G=nx.from_pandas_edgelist(df, 'from', 'to')
 
nx.draw(G)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-ac907f77d98f> in <module>
#      30 #         print (connect)
#      31         network_connections.append(connect)
# ---> 32         for friend in ids(follower):
#      33             connect_ = (follower,friend)
#      34             network_connections.append(connect_)
#
# TypeError: 'list' object is not callable

# %%
import tweepy
import json

consumer_key = "u7L1lnR7HN85dn1qnTFO1cegb"
consumer_secret = "QN1JrEmit2To46ZcwWAT4aI5QGWZXWRDDUPnMCWV5M66SFc8wT"
access_token = "1144377060036620294-BSEicX3zH7hIhksbNZV9mrWFwa07cO"
access_token_secret = "gxWMOodDq1nQAjix9mHEOUSAtgE7XH5ctHInm0XRslJce"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)
user = api.get_user("Zhao")
search_a = api.search(q="Texas AND weather",count=100)
with open("search_results_a.json","a+") as file:
    for tweet in search_a:
        json.dump(tweet._json, file)
        file.write('\n')

search_b = api.search(q="#UNT",count=100,since='2019-11-15', until='2019-11-21')
with open("search_results_b.json","a+") as file:
    for tweet in search_b:
        json.dump(tweet._json, file)
        file.write('\n')
        
search_c = api.search(geocode="41.6746991,-86.3459236,50mi",count=100)
with open("search_results_c.json","a+") as file:
    for tweet in search_c:
        json.dump(tweet._json, file)
        file.write('\n')

# %%
import csv
House = {}
with open(r"C:\Users\zhaow\OneDrive\Desktop\assignment_4_property_tax_report_2019\assignment_4_property_tax_report_2019.csv",'r') as input_file:
    report = csv.reader(input_file) 
    next(report) 
    for item in report: 
        if item[24]:
            if int(item[24]) >= 1900:
                if int(item[24]) in House:
                    House[int(item[24])] +=1
                else:
                    House[int(item[24])] = 1

import matplotlib.pyplot as plt
House_sort = sorted(House.items())
x,y = zip(*House_sort)
plt.plot(x,y,color='C1')
plt.xlabel('Year')
plt.ylabel('House Built', color='C0')
plt.title('Houses built per year',color='C0')
plt.grid(color='C0')
plt.show()

# %%
import csv
House = {} 
with open(r"C:\Users\zhaow\OneDrive\Desktop\assignment_4_property_tax_report_2019\assignment_4_property_tax_report_2019.csv",'r') as input_file:
    Report = csv.reader(input_file) 
    next(Report) 
    for item in Report: 
        if item[24]:
            if int(item[24]) >= 1900:
                if int(item[24]) in House:
                    House[int(item[24])] +=1
                else:
                    House[int(item[24])] = 1

import matplotlib.pyplot as plt
House_sort = sorted(House.items())
x,y = zip(*House_sort)
plt.hist(y, density=1, bins=len(x),color='C1')
plt.xlabel('Number of houses built',color='C0')
plt.ylabel('Frequency',color='C0')
plt.title('Number of houses built per year',color='C0')
plt.grid(color='C0')
plt.show()

# %%
import csv
zones = {} 
with open(r"C:\Users\zhaow\OneDrive\Desktop\assignment_4_property_tax_report_2019\assignment_4_property_tax_report_2019.csv",'r') as input_file:
    Report = csv.reader(input_file) 
    next(Report) 
    for item in Report: 
        if item[5]:
            if item[5] in zones:
                zones[item[5]] +=1
            else:
                zones[item[5]] = 1

import matplotlib.pyplot as plt
labels = list(zones.keys())
sizes = list(zones.values())
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True)
ax1.axis('equal')

plt.show()

# %%
import csv
House = {} 
with open(r"C:\Users\zhaow\OneDrive\Desktop\assignment_4_property_tax_report_2019\assignment_4_property_tax_report_2019.csv",'r') as input_file:
    Report = csv.reader(input_file)
    next(Report)
    for item in Report: 
        if item[24]:
            if int(item[24]) >= 1900:
                if int(item[24]) in House:
                    House[int(item[24])] +=1
                else:
                    House[int(item[24])] = 1

import matplotlib.pyplot as plt
House_sort = sorted(House.items())
x,y = zip(*House_sort)
plt.scatter(x,y,color='C1')
plt.xlabel('Year',color='C0')
plt.ylabel('Number of houses built',color='C0')
plt.title('Number of houses built per year',color='C0')
plt.grid(color='C0')
plt.show()
